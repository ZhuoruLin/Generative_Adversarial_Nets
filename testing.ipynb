# %%
# !python cond_GAN.py --cuda --dataset 'cifar10' --dataroot '../datasets/' --ngpu 2
# Out:
# Namespace(batchSize=64, beta1=0.5, cuda=True, dataroot='../datasets/', dataset='cifar10', emb_size=64, imageSize=64, lr=0.0002, manualSeed=None, ndf=64, netD='', netG='', ngf=64, ngpu=2, niter=25, nz=100, outf='.', workers=2)
# Random Seed:  6848
# Files already downloaded and verified
# _netG (
#   (main): Sequential (
#     (0): ConvTranspose2d(164, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#     (2): ReLU (inplace)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#     (5): ReLU (inplace)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#     (8): ReLU (inplace)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
# ...
